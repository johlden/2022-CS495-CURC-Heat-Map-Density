# %%
import osmnx as ox

# %matplotlib inline
ox.__version__
# Out:
# '1.3.0'

# %%
place = "Fort Collins, Colorado"
tags = {"amenity": "parking"}
gdf = ox.geometries_from_bbox(-105.157357, 40.472606, -104.982001, 40.639352, tags= {"amenity": "parking"})
gdf.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 place = "Fort Collins, Colorado"
#       2 tags = {"amenity": "parking"}
# ----> 3 gdf = ox.geometries_from_bbox(-105.157357, 40.472606, -104.982001, 40.639352, amenity="parking")
#       4 gdf.shape
#
# TypeError: geometries_from_bbox() got an unexpected keyword argument 'amenity'

# %%
fig, ax = ox.plot_footprints(gdf, figsize=(100, 100))

# %%
gdf.head()
